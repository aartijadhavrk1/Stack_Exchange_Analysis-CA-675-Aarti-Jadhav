# %%
import pandas as pd

# %%
file1=pd.read_csv("Cloud Assignment1 files/SEData1.csv")

# %%
file2=pd.read_csv("Cloud Assignment1 files/SEData2.csv")

# %%
file3=pd.read_csv("Cloud Assignment1 files/SEData3.csv")

# %%
file4=pd.read_csv("Cloud Assignment1 files/SEData4.csv")

# %%
#merging file

# %%
mergedfile = pd.concat([file1,file2,file3,file4])

# %%
mergedfile['Body'] = mergedfile['Body'].replace('\n','', regex=True)

# %%
mergedfile['Body']= mergedfile['Body'].str.replace('<[^<]+?>', '')
# Out:
# <ipython-input-21-7762ccd2feb9>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   mergedfile['Body']= mergedfile['Body'].str.replace('<[^<]+?>', '')

# %%
mergedfile
# Out:
#              Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0        927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1       2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2       5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3      16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4       2906582           1         2906586.0       NaN  2010-05-25 16:39:47
# ...         ...         ...               ...       ...                  ...
# 49995     26151           1           26162.0       NaN  2008-08-25 14:47:00
# 49996  52677651           1               NaN       NaN  2018-10-06 09:33:25
# 49997   1857002           1         1862056.0       NaN  2009-12-06 23:26:37
# 49998  12005526           1        22312983.0       NaN  2012-08-17 12:10:10
# 49999  12567956           1        12568053.0       NaN  2012-09-24 15:16:19
#
#        DeletionDate  Score  ViewCount  \
# ...

# %%
mergedfile.to_csv('Cloud Assignment1 files/MergedFileHive1.csv')
